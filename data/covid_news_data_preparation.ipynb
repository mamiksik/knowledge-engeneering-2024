# %% [markdown]
# ### Dataset
#
# dataset was obtained in GDELT Project, specifically from the gdelt-bq project, covid19 dataset, and onlinenews table in Google BigQuery.
# The GDELT Project is a comprehensive initiative that monitors the world's news media, coding and analyzing news events globally.
# The gdelt-bq.covid19.onlinenews table focuses on online news articles related to COVID-19.
# This dataset is widely used for tracking and analyzing media coverage and trends related to the COVID-19 pandemic.
#
# link: https://console.cloud.google.com/bigquery?p=gdelt-bq&d=covid19&t=onlinenews&page=table&pli=1&project=aled7-297920&ws=!1m5!1m4!4m3!1sgdelt-bq!2scovid19!3sonlinenews!1m9!1m8!1m3!1saled7-297920!2sbquxjob_36e9fcb1_18fea093775!3sUS!14m3!1saled7-297920!2sbquxjob_5a2fe995_18fea190b75!3sUS
#
# my filtering:
# - maximum 5 articles per day
# - from '2020-01-01' AND '2022-12-31'
# - topic covid-19 vaccin
# - deleted duplicates

# %%
# WITH RankedArticles AS (
#   SELECT *,
#          ROW_NUMBER() OVER (PARTITION BY DATE(DateTime), LOWER(Title) ORDER BY DateTime) AS title_rn
#   FROM `gdelt-bq.covid19.onlinenews`
#   WHERE
#     (LOWER(Topic) LIKE '%covid-19 vaccin%' OR LOWER(Title) LIKE '%covid-19 vaccin%')
#     AND DATE(DateTime) BETWEEN '2020-01-01' AND '2022-12-31'
# ),
# FilteredArticles AS (
#   SELECT *,
#          ROW_NUMBER() OVER (PARTITION BY DATE(DateTime) ORDER BY DateTime) AS rn
#   FROM RankedArticles
#   WHERE title_rn = 1
# )
# SELECT *
# FROM FilteredArticles
# WHERE rn <= 5

# %% [markdown]
# ### 1. Import Necessary Libraries

# %%
# !pip install pycountry
# Out:
# Collecting pycountry
#   Downloading pycountry-24.6.1-py3-none-any.whl.metadata (12 kB)
# Downloading pycountry-24.6.1-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 23.3 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pycountry
# Successfully installed pycountry-24.6.1

# %%
# Import Necessary Libraries
import numpy as np
import pandas as pd
import re
# import matplotlib.pyplot as plt
# import seaborn as sns
from textblob import TextBlob
# from wordcloud import WordCloud, STOPWORDS
# from geotext import GeoText
# from sklearn.feature_extraction.text import CountVectorizer
# from sklearn.decomposition import LatentDirichletAllocation
import pycountry  # to map country abreviation to full name

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 2. Load the Dataset

# %%
# df = pd.read_csv("/kaggle/input/small-no-sp5000/bquxjob_7eb79e05_18feac2a7a4.csv")
df = pd.read_csv("/kaggle/input/wwwwwwww/bigquery.csv")

print(df.columns)
print(df.shape)
df.info()

df.head()
# Out:
# Index(['Topic', 'DateTime', 'URL', 'Title', 'Context', 'title_rn', 'rn'], dtype='object')
# (5236, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5236 entries, 0 to 5235
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Topic     5236 non-null   object
#  1   DateTime  5236 non-null   object
#  2   URL       5236 non-null   object
#  3   Title     5236 non-null   object
#  4   Context   5236 non-null   object
#  5   title_rn  5236 non-null   int64
#  6   rn        5236 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 286.5+ KB
#      Topic                        DateTime  \
# 0    Cases  2020-02-12 05:02:03.000000 UTC
# 1    Masks  2020-02-12 08:20:01.000000 UTC
# 2  Testing  2020-02-12 12:04:53.000000 UTC
# 3    Cases  2020-02-12 23:32:12.000000 UTC
# 4    Cases  2020-02-13 00:18:29.000000 UTC
#
#                                                  URL  \
# 0  https://www.thestar.com.my/news/nation/2020/02...
# 4     The total death toll in China climbed to 1113....         1   1
# ...                                                 ...       ...  ..
# 5231  VLA2001's manufacturing process, which has alr...         1   1
# 5232  MYTH 8 Covid-19 infection can be contracted fr...         1   2
# 5233  This means the department will publish the COV...         1   3
# 5234  Another important field is the healthcare. It ...         1   4
# 5235  ASCO recommends strategies used with other vac...         1   5
#
# [5236 rows x 7 columns]

# %%
# date column with only YY-mm-dd
df['date'] = pd.to_datetime(df['DateTime']).dt.date

# %%
# Function to extract media and full country name from URL
def extract_media_country_full_name(url):
    # Extract domain name
    media = re.findall(r'://(www\.)?([^/]+)/', url)
    media = media[0][1] if media else ''

    # Extract country code if present in the domain suffix
    country_code = re.findall(r'\.([a-z]{2})(/|$)', url)
    country_code = country_code[0][0] if country_code else ''
    
    # Convert country code to full name using pycountry
    country = ''
    if country_code:
        try:
            country = pycountry.countries.get(alpha_2=country_code.upper()).name
        except AttributeError:
            country = ''
    elif '.com' in url:
        country = 'Global'

    return media, country

# Apply the function to the URL column
df[['media', 'country']] = df['URL'].apply(lambda x: pd.Series(extract_media_country_full_name(x)))

# %% [markdown]
# ### 4. Add companies (sp500 health care sector)

# %%
def fetch_sp500_health_care_companies():
    """Retrieves a list of S&P 500 companies from Wikipedia"""
    url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
    sp500_table = pd.read_html(url)[0]
    health_care_companies = sp500_table[sp500_table['GICS Sector'] == 'Health Care']

    return health_care_companies[['Symbol', 'Security']]

# Fetch the list of S&P 500 companies
sp500_companies_df = fetch_sp500_health_care_companies()
sp500_symbols_list= sp500_companies_df['Symbol'].tolist()
sp500_companies_list = sp500_companies_df['Security'].tolist()
company_to_symbol = dict(zip(sp500_companies_list, sp500_symbols_list))

def extract_companies(text):
    """Extracts mentioned S&P 500 companies and symbols from text"""
    mentioned_companies = [entry for entry in sp500_companies_list if re.search(r'\b' + re.escape(entry) + r'\b', text, re.IGNORECASE)]
    return ', '.join(mentioned_companies) if mentioned_companies else ''

# Apply the function to both Title and Context columns
df['Security'] = df.apply(lambda row: extract_companies(row['Title'] + ' ' + row['Context']), axis=1)
df['Symbol'] = df['Security'].map(company_to_symbol)
df['Symbol'].fillna('', inplace=True)

# %%
# print('number of articles with companies: ', df['Security'].apply(lambda x: x.strip() != '').sum())
# print('articles with companies identified: ', df[df['Security'].apply(lambda x: x.strip() != '')])
# Out:
# number of articles with companies:  938
# articles with companies identified:             Topic                        DateTime  \
# 19         Masks  2020-02-19 00:48:20.000000 UTC
# 37       Testing  2020-02-25 02:32:25.000000 UTC
# 40       Testing  2020-02-25 13:48:33.000000 UTC
# 42       Testing  2020-02-26 03:17:22.000000 UTC
# 43    Quarantine  2020-02-26 04:17:12.000000 UTC
# ...          ...                             ...
# 5210     Covid19  2022-12-26 04:32:32.000000 UTC
# 5217  Quarantine  2022-12-28 01:31:20.000000 UTC
# 5222  Quarantine  2022-12-29 02:16:44.000000 UTC
# 5224     Covid19  2022-12-29 05:46:35.000000 UTC
# 5225     Covid19  2022-12-29 06:32:00.000000 UTC
#
#                                                     URL  \
# 19    http://www.cidrap.umn.edu/news-perspective/202...
# 37    https://www.fool.com/investing/2020/02/24/mode...
# 40    https://www.benzinga.com/general/biotech/20/02...
# 42    https://tribune.net.ph/index.php/2020/02/26/co...
# 43    http://easternontarionetwork.com/index.php/202...
# ...                                                 ...
# 5210  https://www.wfmj.com/story/48030549/new-law-en...
# 5217  https://www.johnsoncitypress.com/ap/politics/n...
# 5222  https://www.nbcmiami.com/news/national-interna...
# 5224            https://armenpress.am/eng/news/1067043/
# 5225  https://menafn.com/1105364155/QRCS-Monitors-Ph...
#
#                                                   Title  \
# 19    HHS partners with drug makers on COVID-19 vacc...
# 37    Moderna's New COVID-19 Vaccine Ready for Human...
# 40    (MNK),  (MRNA) - The Daily Biotech Pulse: Mode...
# 42            COVID-19 vaccine test underway | Business
# 43    Shares in U.S. drug maker Moderna soar after p...
# ...                                                 ...
# 5210  New law ends COVID-19 vaccine mandate for US t...
# 5217  New law ends COVID-19 vaccine mandate for US t...
# 5222  Congress Ends COVID-19 Vaccine Mandate for US ...
# 5224  From Macron's visit to donation of COVID-19 va...
# 5225  QRCS Monitors Phase 2 Of COVID-19 Vaccination ...
#
#                                                 Context  title_rn  rn  \
# 19    The US Department of Health and Human Services...         1   1
# 37    This is because DNA-based vaccines need to int...         1   1
# 40    Here's a roundup of top developments in the bi...         1   4
# 42    A biotech company in Massachusetts has created...         1   1
# 43    Gilead Sciences also has approval for the clin...         1   2
# ...                                                 ...       ...  ..
# 5210  Thousands of others have sought religious and ...         1   5
# 5217  Thousands of others have sought religious and ...         1   2
# 5222  Sign up for NBC South Florida newsletters. The...         1   2
# 5224  What vaccines the statement is about and when ...         1   4
# 5225  Through 50 vaccination stations and over 100 m...         1   5
#
#             date                      media      country  \
# 19    2020-02-19             cidrap.umn.edu
# 37    2020-02-25                   fool.com       Global
# 40    2020-02-25               benzinga.com       Global
# 42    2020-02-26             tribune.net.ph  Philippines
# 43    2020-02-26  easternontarionetwork.com       Global
# ...          ...                        ...          ...
# 5210  2022-12-26                   wfmj.com       Global
# 5217  2022-12-28       johnsoncitypress.com       Global
# 5222  2022-12-29               nbcmiami.com       Global
# 5224  2022-12-29              armenpress.am      Armenia
# 5225  2022-12-29                 menafn.com       Global
#
#                       Security Symbol
# 19           Johnson & Johnson    JNJ
# 37                     Moderna   MRNA
# 40    Gilead Sciences, Moderna
# 42                     Moderna   MRNA
# 43    Gilead Sciences, Moderna
# ...                        ...    ...
# 5210                    Pfizer    PFE
# 5217                    Pfizer    PFE
# 5222                    Pfizer    PFE
# 5224           Moderna, Pfizer
# 5225         Johnson & Johnson    JNJ
#
# [938 rows x 12 columns]

# %% [markdown]
# ### 5. Filter columns and save

# %%
df_covid = df[['Topic', 'Title', 'Context','date','media','country', 'Security','Symbol' ]]
df_covid[1:20]
# Out:
#                Topic                                              Title  \
# 1              Masks  San Diego lab discovers COVID-19 vaccine in 3 ...
# %%
# Save the modified DataFrame to a new CSV file
output_file_path = '/kaggle/working/df_covid.csv'
df_covid.to_csv(output_file_path, index=False)

output_file_path
# Out:
# '/kaggle/working/df_covid.csv'

# %% [markdown]
# ### 6. Sentiment Analysis using TextBlob
# Analyze the sentiment of each tweet using TextBlob.
# - polarity: emotional tone of the text (positive, negative, or neutral).
# - subjectivity: if text is more opinion-based or fact-based.

# %%
# Sentiment Analysis using TextBlob
def get_sentiment(text):
    blob = TextBlob(text)
    sentiment = blob.sentiment.polarity
    return sentiment

# def get_subjectivity(text):
#     analysis = TextBlob(text)
#     return analysis.sentiment.subjectivity

# Apply the sentiment function to the Title and Context columns
df_covid['title_sentiment'] = df_covid['Title'].apply(get_sentiment)
df_covid['context_sentiment'] = df_covid['Context'].apply(get_sentiment)
df_covid['sentiment'] = df_covid[['title_sentiment', 'context_sentiment']].mean(axis=1)

# df_covid['title_subjectivity'] = df_covid['Title'].apply(get_subjectivity)
# df_covid['context_subjectivity'] = df_covid['Context'].apply(get_subjectivity)
# df_covid['combined_subjectivity'] = df_covid[['title_subjectivity', 'context_subjectivity']].mean(axis=1)

# %%
df_covid[1:20]
# Out:
#                Topic                                              Title  \
# 1              Masks  San Diego lab discovers COVID-19 vaccine in 3 ...
# 2            Testing  J&J strengthens R&D into COVID-19 vaccine with...
# 3              Cases  Coronavirus outbreak: COVID-19 vaccine candida...
# 4              Cases  Coronavirus outbreak: COVID-19 vaccine candida...
# 5              Masks  San Diego lab discovers COVID-19 vaccine in 3 ...
# 6            Covid19  WHO chief says first Covid-19 vaccine could be...
# 7   SocialDistancing  As scientists race to produce Covid-19 vaccine...
# 8              Masks  San Diego lab discovers COVID-19 vaccine in 3 ...
# 9         Quarantine      China Hobbles Efforts Toward COVID-19 Vaccine
# 10             Masks  Covid-19 vaccine in late February: White House...
# 11           Covid19        Finding a COVID-19 vaccine is the easy part
# 12           Testing  Taiwan firm teams up with US to develop Covid-...
# 13           Testing  Taiwanese firm teams up with US to develop Cov...
# 14           Testing  Virus outbreak: Medigen to work on COVID-19 va...
# 15             Masks  Here's why World Health Organisation says we h...
# 16           Testing  《TAIPEI TIMES》 Medigen to work on COVID-19 vac...
# 17           Testing     China speeding up COVID-19 vaccine development
# 18           Covid19  Sanofi Gets Backing From U.S. Government to De...
# 19             Masks  HHS partners with drug makers on COVID-19 vacc...
#
#                                               Context        date  \
# 1   As the days go by, Inovio Pharmaceuticals is g...  2020-02-12
# 2   The collaborative partnership with BARDA build...  2020-02-12
# 3   The total death toll in China climbed to 1113....  2020-02-12
# 4   The total death toll in China climbed to 1113....  2020-02-13
# 5   As the days go by, Inovio Pharmaceuticals is g...  2020-02-13
# 6   Tedros reiterated the need to use available re...  2020-02-14
# 7   By Analou De Vera An official of the World Hea...  2020-02-14
# 8   As the days go by, Inovio Pharmaceuticals is g...  2020-02-14
# 9   As former CDC chief Tom Friedman noted recentl...  2020-02-14
# 10  A US biotech firm Gilead announced earlier thi...  2020-02-16
# 11  Vaccine makers want to trounce the coronavirus...  2020-02-16
# 12  It is MVC's second cooperation with the NIH si...  2020-02-17
# 13  It is MVC's second cooperation with the NIH si...  2020-02-17
# 14  Medigen Vaccine Biologics Corp (高端疫苗) would co...  2020-02-17
# 15  This will be an animal model that gives us clu...  2020-02-17
# 16  《TAIPEI TIMES》 Medigen to work on COVID-19 vac...  2020-02-17
# 17  The epidemic outbreak has resulted in 1,868 de...  2020-02-18
# 18  Through the Biomedical Advanced Research and D...  2020-02-18
# 19  The US Department of Health and Human Services...  2020-02-19
#
#                     media                    country           Security Symbol
# 1                cbs8.com                     Global
# 2        pharmaphorum.com                     Global
# 3           theage.com.au                  Australia
# 4          watoday.com.au                  Australia
# 5                wtol.com                     Global
# 6   freemalaysiatoday.com                     Global
# 7          news.mb.com.ph                Philippines
# 8           13newsnow.com                     Global
# 9       theepochtimes.com                     Global
# 10               dawn.com                     Global
# 11                afr.com                     Global
# 12         thestar.com.my                   Malaysia
# 13       malaysiakini.com                     Global
# 14        taipeitimes.com                     Global
# 15              scroll.in                      India
# 16        news.ltn.com.tw  Taiwan, Province of China
# 17                ecns.cn                      China
# 18               fool.com                     Global
# 19         cidrap.umn.edu                             Johnson & Johnson    JNJ

# %%
# Calculate the average sentiment for each day
mean_sentiment_per_day = df_covid.groupby('date')['sentiment'].mean().reset_index()
mean_sentiment_per_day.rename(columns={'sentiment': 'day_sentiment'}, inplace=True)

# Merge to dataframe
df_covid = df_covid.merge(mean_sentiment_per_day, on='date', how='left')

# %%
def categorize_sentiment(score):
    if score > 0:
        return 'positive'
    elif score < 0:
        return 'negative'
    else:
        return 'neutral'

df_covid['sentiment_cat'] = df_covid['sentiment'].apply(categorize_sentiment)
df_covid['day_sent_cat'] = df_covid['day_sentiment'].apply(categorize_sentiment)

# %% [markdown]
# ### 7. Add day before and day after

# %%
# Add daybefore and dayafter columns

df_covid['daybefore'] = df_covid['date'] - pd.Timedelta(days=1)
df_covid['dayafter'] = df_covid['date'] + pd.Timedelta(days=1)

# %%
# Add the average sentiment for daybefore and dayafter
day_before_sent_cat = mean_sentiment_per_day[['date', 'day_sentiment']].copy()
day_before_sent_cat['date'] = day_before_sent_cat['date'] + pd.Timedelta(days=1)
day_before_sent_cat.rename(columns={'day_sentiment': 'dayBefore_sent_cat'}, inplace=True)

day_after_sent_cat = mean_sentiment_per_day[['date', 'day_sentiment']].copy()
day_after_sent_cat['date'] = day_after_sent_cat['date'] - pd.Timedelta(days=1)
day_after_sent_cat.rename(columns={'day_sentiment': 'dayAfter_sent_cat'}, inplace=True)

# Merge the day_before and day_after sentiment categories back to the original dataframe
df_covid = df_covid.merge(day_before_sent_cat, on='date', how='left')
df_covid = df_covid.merge(day_after_sent_cat, on='date', how='left')

# %%
# Save the modified DataFrame to a new CSV file
output_file_path = '/kaggle/working/df_covid.csv'
df_covid.to_csv(output_file_path, index=False)

output_file_path
# Out:
# '/kaggle/working/df_covid.csv'

# %% [markdown]
# ### Remove

# %%
# columns_to_remove = ['dayAfter_sent_cat']  # Replace with actual column names to be removed
# df_covid.drop(columns=columns_to_remove, inplace=True)

# %%
# df_covid =  pd.read_csv("/kaggle/input/qqqqqq/df_covid (2).csv")
# df_covid['Symbol'].fillna('', inplace=True)
# df_covid['Security'].fillna('', inplace=True)
# df_covid['date'] = pd.to_datetime(df_covid['date']).dt.date

# %%
df_covid[1:20]
# Out:
#                Topic                                              Title  \
# 1              Masks  San Diego lab discovers COVID-19 vaccine in 3 ...
# 2            Testing  J&J strengthens R&D into COVID-19 vaccine with...
# 3              Cases  Coronavirus outbreak: COVID-19 vaccine candida...
# 4              Cases  Coronavirus outbreak: COVID-19 vaccine candida...
# 5              Masks  San Diego lab discovers COVID-19 vaccine in 3 ...
# 6            Covid19  WHO chief says first Covid-19 vaccine could be...
# 7   SocialDistancing  As scientists race to produce Covid-19 vaccine...
# 8              Masks  San Diego lab discovers COVID-19 vaccine in 3 ...
# 9         Quarantine      China Hobbles Efforts Toward COVID-19 Vaccine
# 10             Masks  Covid-19 vaccine in late February: White House...
# 11           Covid19        Finding a COVID-19 vaccine is the easy part
# 12           Testing  Taiwan firm teams up with US to develop Covid-...
# 13           Testing  Taiwanese firm teams up with US to develop Cov...
# 14           Testing  Virus outbreak: Medigen to work on COVID-19 va...
# 15             Masks  Here's why World Health Organisation says we h...
# 16           Testing  《TAIPEI TIMES》 Medigen to work on COVID-19 vac...
# 17           Testing     China speeding up COVID-19 vaccine development
# 18           Covid19  Sanofi Gets Backing From U.S. Government to De...
# 19             Masks  HHS partners with drug makers on COVID-19 vacc...
#
#                                               Context        date  \
# 1   As the days go by, Inovio Pharmaceuticals is g...  2020-02-12
# 2   The collaborative partnership with BARDA build...  2020-02-12
# 3   The total death toll in China climbed to 1113....  2020-02-12
# 4   The total death toll in China climbed to 1113....  2020-02-13
# 5   As the days go by, Inovio Pharmaceuticals is g...  2020-02-13
# 6   Tedros reiterated the need to use available re...  2020-02-14
# 7   By Analou De Vera An official of the World Hea...  2020-02-14
# 8   As the days go by, Inovio Pharmaceuticals is g...  2020-02-14
# 9   As former CDC chief Tom Friedman noted recentl...  2020-02-14
# 10  A US biotech firm Gilead announced earlier thi...  2020-02-16
# 11  Vaccine makers want to trounce the coronavirus...  2020-02-16
# 12  It is MVC's second cooperation with the NIH si...  2020-02-17
# 13  It is MVC's second cooperation with the NIH si...  2020-02-17
# 14  Medigen Vaccine Biologics Corp (高端疫苗) would co...  2020-02-17
# 15  This will be an animal model that gives us clu...  2020-02-17
# 16  《TAIPEI TIMES》 Medigen to work on COVID-19 vac...  2020-02-17
# 17  The epidemic outbreak has resulted in 1,868 de...  2020-02-18
# 18  Through the Biomedical Advanced Research and D...  2020-02-18
# 19  The US Department of Health and Human Services...  2020-02-19
#
#                     media                    country           Security  \
# 1                cbs8.com                     Global
# 2        pharmaphorum.com                     Global
# 3           theage.com.au                  Australia
# 4          watoday.com.au                  Australia
# 5                wtol.com                     Global
# 6   freemalaysiatoday.com                     Global
# 7          news.mb.com.ph                Philippines
# 8           13newsnow.com                     Global
# 9       theepochtimes.com                     Global
# 10               dawn.com                     Global
# 11                afr.com                     Global
# 12         thestar.com.my                   Malaysia
# 13       malaysiakini.com                     Global
# 14        taipeitimes.com                     Global
# 15              scroll.in                      India
# 16        news.ltn.com.tw  Taiwan, Province of China
# 17                ecns.cn                      China
# 18               fool.com                     Global
# 19         cidrap.umn.edu                             Johnson & Johnson
#
#    Symbol  title_sentiment  context_sentiment  sentiment  day_sentiment  \
# 1                 0.000000          -0.200000  -0.100000      -0.008153
# 2                 0.000000           0.115000   0.057500      -0.008153
# 3                 0.000000           0.182273   0.091136      -0.008153
# 4                 0.000000           0.182273   0.091136      -0.004432
# 5                 0.000000          -0.200000  -0.100000      -0.004432
# 6                 0.225000           0.194444   0.209722       0.063356
# 7                 0.100000           0.107407   0.103704       0.063356
# 8                 0.000000          -0.200000  -0.100000       0.063356
# 9                 0.000000           0.080000   0.040000       0.063356
# 10               -0.150000          -0.060000  -0.105000       0.071458
# 11                0.433333           0.062500   0.247917       0.071458
# 12               -0.200000           0.188889  -0.005556       0.032361
# 13               -0.200000           0.188889  -0.005556       0.032361
# 14                0.000000           0.000000   0.000000       0.032361
# 15                0.000000           0.408333   0.204167       0.032361
# 16                0.000000          -0.062500  -0.031250       0.032361
# 17                0.000000          -0.033333  -0.016667       0.016667
# 18                0.000000           0.100000   0.050000       0.016667
# 19    JNJ         0.000000           0.161905   0.080952       0.136824
#
#    sentiment_cat day_sent_cat   daybefore    dayafter  dayBefore_sent_cat  \
# 1       negative     negative  2020-02-11  2020-02-13                 NaN
# 2       positive     negative  2020-02-11  2020-02-13                 NaN
# 3       positive     negative  2020-02-11  2020-02-13                 NaN
# 4       positive     negative  2020-02-12  2020-02-14           -0.008153
# 5       negative     negative  2020-02-12  2020-02-14           -0.008153
# 6       positive     positive  2020-02-13  2020-02-15           -0.004432
# 7       positive     positive  2020-02-13  2020-02-15           -0.004432
# 8       negative     positive  2020-02-13  2020-02-15           -0.004432
# 9       positive     positive  2020-02-13  2020-02-15           -0.004432
# 10      negative     positive  2020-02-15  2020-02-17                 NaN
# 11      positive     positive  2020-02-15  2020-02-17                 NaN
# 12      negative     positive  2020-02-16  2020-02-18            0.071458
# 13      negative     positive  2020-02-16  2020-02-18            0.071458
# 14       neutral     positive  2020-02-16  2020-02-18            0.071458
# 15      positive     positive  2020-02-16  2020-02-18            0.071458
# 16      negative     positive  2020-02-16  2020-02-18            0.071458
# 17      negative     positive  2020-02-17  2020-02-19            0.032361
# 18      positive     positive  2020-02-17  2020-02-19            0.032361
# 19      positive     positive  2020-02-18  2020-02-20            0.016667
#
#     dayAfter_sent_cat
# 1           -0.004432
# 2           -0.004432
# 3           -0.004432
# 4            0.063356
# 5            0.063356
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10           0.032361
# 11           0.032361
# 12           0.016667
# 13           0.016667
# 14           0.016667
# 15           0.016667
# 16           0.016667
# 17           0.136824
# 18           0.136824
# 19           0.012858
